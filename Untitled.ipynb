# %%
import numpy as np
import welly
import pandas as pd
import matplotlib.pyplot as plt
import Stdlog

# %%
well2 = Stdlog.stdlog(r"tutorial/WellX-2.las")

# %%
d = {
    'GR': 'GR',
    'CALI': 'CALI',
    'DEPTH': 'DEPTH',
    'TVD': 'TVD',
    'LL9S': 'LL9S',
    'LL9D': 'LL9D',
    'MSFL': 'MSFL',
    'RT': 'RT',
    'RX0': 'RX0',
    'CNL': 'CNL',
    'DENS': 'DENS',
    'SONI': 'SONI'
}

# %%
well2.visualize(d, pltrange=(9900, 13000), 
             tracks = [['GR', 'CALI'], ['DEPTH','TVD'],['LL9D', 'LL9S'],['MSFL', 'RT', 'RX0'], ['DENS', 'CNL', 'SONI']],
            sbsline= (87, 'shaded'))
# Out:
# /home/mirzakhan/Desktop/FDP/Stdlog/Stdlog.py:205: RuntimeWarning: invalid value encountered in less
#   ax.fill_betweenx(y, val, x2, where = x2<val, interpolate = True, color = '#d6cc0b')
# <module 'matplotlib.pyplot' from '/home/mirzakhan/.local/share/virtualenvs/Stdlog-xUKvEn9n/lib/python3.6/site-packages/matplotlib/pyplot.py'>
