# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.lines as mlines 
import welly
import lasio
import Stdlog
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-41eb27b27e3c> in <module>
#       4 import welly
#       5 import lasio
# ----> 6 import Stdlog
#
# ModuleNotFoundError: No module named 'Stdlog'

# %%
well1 = Stdlog.stdlog(r"X1 Logs Folder/WellX-1.las")

# %%
d = {
    'GR': 'GR',
    'CALI': 'CALI',
    'DEPTH': 'DEPTH',
    'TVD': 'TVD',
    'LL9S': 'LL9S',
    'LL9D': 'LL9D',
    'MSFL': 'MSFL',
    'RT': 'RT',
    'RX0': 'RX0',
    'CNL': 'CNL',
    'DENS': 'DENS',
    'SONI': 'SONI'
}

# %%
well1.visualize(d, pltrange=(9900, 13000), 
             tracks = [['GR', 'CALI'], ['DEPTH','TVD'],['LL9D', 'LL9S'],['MSFL', 'RT', 'RX0'], ['DENS', 'CNL'],['SONI']],
            sbsline=(125, 'None'))
# Out:
# <module 'matplotlib.pyplot' from '/home/mirzakhan/.local/share/virtualenvs/FDP-DATA-SWoavXvS/lib/python3.6/site-packages/matplotlib/pyplot.py'>
